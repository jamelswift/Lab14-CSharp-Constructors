// %% [markdown]
// # Lab 13 Exercise 3

// %% [markdown]
// ## Constructors

// %% [markdown]
// 1.สร้าง console application project
//
// ```cmd
// dotnet new console --name Lab13_Ex03
// ```

// %% [markdown]
// 2.เปลี่ยน code ให้เป็นดังต่อไปนี้
//
// ```csharp
// var circle = new Circle();
// var rectangle = new Rectangle();
// var triangle = new Triangle();
//
// class Shape
// {
//     private int? NumOfSide;
//     public Shape()
//     {
//         System.Console.WriteLine("This is some shape with unknown side");
//     }
//     public Shape(int NumOfSide)
//     {
//         System.Console.WriteLine($"This is some shape with {NumOfSide} sides" );
//     }
// }
// class Circle :Shape
// {
//     public Circle():base()
//     {
//         System.Console.WriteLine("This is a circle");
//     }
// }
// class Rectangle :Shape
// {
//     public Rectangle(): base(4)
//     {
//         System.Console.WriteLine("This is a rectangle");
//     }
// }
// class Triangle :Shape
// {
//    public Triangle() : base(3)
//     {
//         System.Console.WriteLine("This is a triangle");
//     }
// }
// ```

// %% [markdown]
// 3.Build project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet build  Lab13_Ex03
// ```
//
// ถ้ามีที่ผิดพลาดในโปรแกรม ให้แก้ไขให้ถูกต้อง

// %% [markdown]
// 4.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 5.Run project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet run --project Lab13_Ex03
// ```

// %% [markdown]
// 6.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 7.อธิบายสิ่งที่พบในการทดลอง

// %% [markdown]
// สรุป:
//
// ในโค้ดนี้, คุณใช้ คอนสตรัคเตอร์ที่มีหลายรูปแบบ (Overloaded Constructors) และ การสืบทอด (Inheritance) เพื่อให้คลาสลูก (Circle, Rectangle, Triangle) เรียกคอนสตรัคเตอร์ของคลาสแม่ (Shape) ซึ่งทำให้เกิดการพิมพ์ข้อความที่ต่างกันตามจำนวนด้านของรูปร่างแต่ละประเภท. การใช้ base() ช่วยให้คลาสลูกสามารถเรียกคอนสตรัคเตอร์ของคลาสแม่ได้, ซึ่งช่วยให้มีความยืดหยุ่นในการส่งข้อมูลจากคลาสลูกไปยังคลาสแม่.
